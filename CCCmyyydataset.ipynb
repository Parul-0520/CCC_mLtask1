# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
plt.rcParams['font.family'] = 'sans-serif'
import seaborn as sns
plt.style.use('ggplot')

# %%
df=pd.read_csv("C:\\Users\\parul\\OneDrive\\Desktop\\mydataset.csv")

# %%
df.shape
# Out:
# (934, 11)

# %%
df.head()
# Out:
#           id  bedrooms  bathrooms    tenure  garden  \
# 0  132180206       5.0        4.0  freehold       0
# 1  134996630       6.0        5.0  freehold       0
# 2  134169233       7.0        5.0  freehold       1
# 3  132180206       5.0        4.0  freehold       0
# 4  134996630       6.0        5.0  freehold       0
#
#                                       street  size_sqft  price_pounds  \
# 0                     Ladbroke Grove, London        NaN      10500000
# 1       Murray Road, Wimbledon Village, SW19        NaN       8950000
# 2  Southside Common, Wimbledon Village, SW19        NaN      11950000
# 3                     Ladbroke Grove, London        NaN      10500000
# 4       Murray Road, Wimbledon Village, SW19        NaN       8950000
#
#    nearest_station_name  nearest_station_miles postcode_outer
# 0  Holland Park Station                    0.2            NaN
# 1     Wimbledon Station                    0.3           SW19
# ...

# %%
df.columns
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'tenure', 'garden', 'street',
#        'size_sqft', 'price_pounds', 'nearest_station_name',
#        'nearest_station_miles', 'postcode_outer'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                         int64
# bedrooms                 float64
# bathrooms                float64
# tenure                    object
# garden                     int64
# street                    object
# size_sqft                float64
# price_pounds               int64
# nearest_station_name      object
# nearest_station_miles    float64
# postcode_outer            object
# dtype: object

# %%
df.describe()
# Out:
#                  id    bedrooms   bathrooms      garden     size_sqft  \
# count  9.340000e+02  919.000000  899.000000  934.000000    417.000000
# mean   1.269162e+08    4.965180    4.538376    0.760171   3448.158273
# std    1.367926e+07    2.262916    2.070427    0.777689   3926.664533
# min    6.825453e+07    1.000000    1.000000    0.000000      0.000000
# 25%    1.259347e+08    3.000000    3.000000    0.000000      0.000000
# 50%    1.318950e+08    5.000000    4.000000    1.000000   2842.000000
# 75%    1.347572e+08    6.000000    5.000000    1.000000   4488.000000
# max    1.368231e+08   28.000000   20.000000    4.000000  27790.000000
#
#        price_pounds  nearest_station_miles
# count  9.340000e+02             934.000000
# mean   1.104846e+07               0.369272
# std    6.892229e+06               0.382982
# min    2.000000e+05               0.000000
# 25%    7.000000e+06               0.200000
# 50%    9.000000e+06               0.300000
# ...

# %%
#WHEN DEALING WITH LARGE DT:-
    #creating a subset of data
    #removing columns which I don't want to deal with 
#WHEN DEALING WITH SMALL DT LIKE THIS:-
    #df.drop(['size_sqft'], axis=1)                        axis=1 to tell it that it's a column

df[['id', 'bedrooms', 'bathrooms', 'tenure', 'garden', 'street',
       #'size_sqft',
    'price_pounds', 'nearest_station_name',
       'nearest_station_miles', 'postcode_outer']].copy()
# Out:
#             id  bedrooms  bathrooms     tenure  garden  \
# 0    132180206       5.0        4.0   freehold       0
# 1    134996630       6.0        5.0   freehold       0
# 2    134169233       7.0        5.0   freehold       1
# 3    132180206       5.0        4.0   freehold       0
# 4    134996630       6.0        5.0   freehold       0
# ..         ...       ...        ...        ...     ...
# 929  133206317       4.0        3.0  leasehold       1
# 930  133510934       7.0        6.0   freehold       1
# 931  132058628       2.0        2.0  leasehold       0
# 932  127761875       3.0        3.0  leasehold       0
# 933  129762833       3.0        3.0  leasehold       1
#
#                                               street  price_pounds  \
# 0                             Ladbroke Grove, London      10500000
# 1               Murray Road, Wimbledon Village, SW19       8950000
# 2          Southside Common, Wimbledon Village, SW19      11950000
# ...

# %%
df.dtypes
# Out:
# id                         int64
# bedrooms                 float64
# bathrooms                float64
# tenure                    object
# garden                     int64
# street                    object
# size_sqft                float64
# price_pounds               int64
# nearest_station_name      object
# nearest_station_miles    float64
# postcode_outer            object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'tenure', 'garden', 'street',
#        'size_sqft', 'price_pounds', 'nearest_station_name',
#        'nearest_station_miles', 'postcode_outer'],
#       dtype='object')

# %%
df.rename(columns={'id':'ID', 'bedrooms':'Bedrooms', 'bathrooms':'Bathrooms', 'tenure':'Tenure', 'garden':'Garden', 'street':'Street','size_sqft':'Size in sqft','price_pounds':'Price in Pounds', 'nearest_station_name':'Nearest Station', 'nearest_station_miles':'Nearest Station (miles)', 'postcode_outer':'Postcode (outward code)'})
# Out:
#             ID  Bedrooms  Bathrooms     Tenure  Garden  \
# 0    132180206       5.0        4.0   freehold       0
# 1    134996630       6.0        5.0   freehold       0
# 2    134169233       7.0        5.0   freehold       1
# 3    132180206       5.0        4.0   freehold       0
# 4    134996630       6.0        5.0   freehold       0
# ..         ...       ...        ...        ...     ...
# 929  133206317       4.0        3.0  leasehold       1
# 930  133510934       7.0        6.0   freehold       1
# 931  132058628       2.0        2.0  leasehold       0
# 932  127761875       3.0        3.0  leasehold       0
# 933  129762833       3.0        3.0  leasehold       1
#
#                                               Street  Size in sqft  \
# 0                             Ladbroke Grove, London           NaN
# 1               Murray Road, Wimbledon Village, SW19           NaN
# 2          Southside Common, Wimbledon Village, SW19           NaN
# ...

# %%
#if there is NaN value then true, else false
df.isna()
# Out:
#         ID  Bedrooms  Bathrooms  Tenure  Garden  Street  Size in sqft  \
# 0    False     False      False   False   False   False          True
# 1    False     False      False   False   False   False          True
# 2    False     False      False   False   False   False          True
# 3    False     False      False   False   False   False          True
# 4    False     False      False   False   False   False          True
# ..     ...       ...        ...     ...     ...     ...           ...
# 929  False     False      False   False   False   False          True
# 930  False     False      False   False   False   False         False
# 931  False     False      False   False   False   False          True
# 932  False     False      False   False   False   False         False
# 933  False     False      False   False   False   False          True
#
#      Price in Pounds  Nearest Station  Nearest Station (miles)  \
# ...

# %%
df.isna().sum()
# Out:
# ID                           0
# Bedrooms                    15
# Bathrooms                   35
# Tenure                      12
# Garden                       0
# Street                       0
# Size in sqft               517
# Price in Pounds              0
# Nearest Station              0
# Nearest Station (miles)      0
# Postcode (outward code)    137
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 929    False
# 930    False
# 931    False
# 932    False
# 933    False
# Length: 934, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
#             ID  Bedrooms  Bathrooms     Tenure  Garden  \
# 3    132180206       5.0        4.0   freehold       0
# 4    134996630       6.0        5.0   freehold       0
# 5    134169233       7.0        5.0   freehold       1
# 12   132180206       5.0        4.0   freehold       0
# 13   134996630       6.0        5.0   freehold       0
# ..         ...       ...        ...        ...     ...
# 577  136719080       3.0        3.0   freehold       3
# 718  132892601       NaN        NaN        NaN       1
# 747   85156008       3.0        4.0  leasehold       1
# 791  127510283       9.0        9.0        NaN       0
# 839  127510241       9.0        9.0        NaN       0
#
#                                                 Street  Size in sqft  \
# 3                               Ladbroke Grove, London           NaN
# 4                 Murray Road, Wimbledon Village, SW19           NaN
# 5            Southside Common, Wimbledon Village, SW19           NaN
# ...

# %%
#rows that occur twice
df.loc[df.duplicated(subset=['Bedrooms'])]
# Out:
#             ID  Bedrooms  Bathrooms     Tenure  Garden  \
# 3    132180206       5.0        4.0   freehold       0
# 4    134996630       6.0        5.0   freehold       0
# 5    134169233       7.0        5.0   freehold       1
# 6    124365635       6.0        6.0   freehold       1
# 7    132654419       6.0        4.0   freehold       1
# ..         ...       ...        ...        ...     ...
# 929  133206317       4.0        3.0  leasehold       1
# 930  133510934       7.0        6.0   freehold       1
# 931  132058628       2.0        2.0  leasehold       0
# 932  127761875       3.0        3.0  leasehold       0
# 933  129762833       3.0        3.0  leasehold       1
#
#                                               Street  Size in sqft  \
# 3                             Ladbroke Grove, London           NaN
# 4               Murray Road, Wimbledon Village, SW19           NaN
# 5          Southside Common, Wimbledon Village, SW19           NaN
# ...

# %%
df.loc[df.duplicated(subset=['Bedrooms'])].head(5)
# Out:
#           ID  Bedrooms  Bathrooms    Tenure  Garden  \
# 3  132180206       5.0        4.0  freehold       0
# 4  134996630       6.0        5.0  freehold       0
# 5  134169233       7.0        5.0  freehold       1
# 6  124365635       6.0        6.0  freehold       1
# 7  132654419       6.0        4.0  freehold       1
#
#                                       Street  Size in sqft  Price in Pounds  \
# 3                     Ladbroke Grove, London           NaN         10500000
# 4       Murray Road, Wimbledon Village, SW19           NaN          8950000
# 5  Southside Common, Wimbledon Village, SW19           NaN         11950000
# 6             Chesterfield Hill, London, W1J        4460.0         10950000
# 7             Cottesmore Gardens, London, W8           NaN         18500000
#
#                   Nearest Station  Nearest Station (miles)  \
# 3            Holland Park Station                      0.2
# 4               Wimbledon Station                      0.3
# ...

# %%
df.query('Bedrooms=="5.0"')
# Out:
# Empty DataFrame
# Columns: [ID, Bedrooms, Bathrooms, Tenure, Garden, Street, Size in sqft, Price in Pounds, Nearest Station, Nearest Station (miles), Postcode (outward code)]
# Index: []

# %%
df.loc[df.duplicated(subset=['Street'])].head(5)
# Out:
#            ID  Bedrooms  Bathrooms    Tenure  Garden  \
# 3   132180206       5.0        4.0  freehold       0
# 4   134996630       6.0        5.0  freehold       0
# 5   134169233       7.0        5.0  freehold       1
# 12  132180206       5.0        4.0  freehold       0
# 13  134996630       6.0        5.0  freehold       0
#
#                                        Street  Size in sqft  Price in Pounds  \
# 3                      Ladbroke Grove, London           NaN         10500000
# 4        Murray Road, Wimbledon Village, SW19           NaN          8950000
# 5   Southside Common, Wimbledon Village, SW19           NaN         11950000
# 12                     Ladbroke Grove, London           NaN         10500000
# 13       Murray Road, Wimbledon Village, SW19           NaN          8950000
#
#          Nearest Station  Nearest Station (miles) Postcode (outward code)
# 3   Holland Park Station                      0.2                     NaN
# ...

# %%
df.query('Street=="Ladbroke Grove, London"')
# Out:
#            ID  Bedrooms  Bathrooms    Tenure  Garden                  Street  \
# 0   132180206       5.0        4.0  freehold       0  Ladbroke Grove, London
# 3   132180206       5.0        4.0  freehold       0  Ladbroke Grove, London
# 12  132180206       5.0        4.0  freehold       0  Ladbroke Grove, London
#
#     Size in sqft  Price in Pounds       Nearest Station  \
# 0            NaN         10500000  Holland Park Station
# 3            NaN         10500000  Holland Park Station
# 12           NaN         10500000  Holland Park Station
#
#     Nearest Station (miles) Postcode (outward code)
# 0                       0.2                     NaN
# 3                       0.2                     NaN
# 12                      0.2                     NaN

# %%
df.columns
# Out:
# Index(['ID', 'Bedrooms', 'Bathrooms', 'Tenure', 'Garden', 'Street',
#        'Size in sqft', 'Price in Pounds', 'Nearest Station',
#        'Nearest Station (miles)', 'Postcode (outward code)'],
#       dtype='object')

# %%
df.loc[~df.duplicated(subset=['Street', 'Nearest Station', 'Postcode (outward code)'])].reset_index(drop=True)
# Out:
#             ID  Bedrooms  Bathrooms     Tenure  Garden  \
# 0    132180206       5.0        4.0   freehold       0
# 1    134996630       6.0        5.0   freehold       0
# 2    134169233       7.0        5.0   freehold       1
# 3    124365635       6.0        6.0   freehold       1
# 4    132654419       6.0        4.0   freehold       1
# ..         ...       ...        ...        ...     ...
# 705  132021563       8.0        9.0   freehold       1
# 706  133206317       4.0        3.0  leasehold       1
# 707  133510934       7.0        6.0   freehold       1
# 708  127761875       3.0        3.0  leasehold       0
# 709  129762833       3.0        3.0  leasehold       1
#
#                                                 Street  Size in sqft  \
# 0                               Ladbroke Grove, London           NaN
# 1                 Murray Road, Wimbledon Village, SW19           NaN
# 2            Southside Common, Wimbledon Village, SW19           NaN
# ...

# %%
df['Street'].value_counts()
# Out:
# Street
# Moxon Street, London, W1U                   8
# Winnington Road, N2                         8
# Moxon Street, W1U                           7
# Canary Wharf,\r\nLondon, \r\nE14 9QG        5
# Chesham Street, SW1X                        5
#                                            ..
# Eaton Place, London, SW1X                   1
# Connaught Place, Hyde Park, London, W2.     1
# Tite Street, London, SW3                    1
# Kenwood House, Harper Lane, Radlett, WD7    1
# Principal Tower, City of London             1
# Name: count, Length: 703, dtype: int64

# %%
df['Street'].value_counts().head(10)
# Out:
# Street
# Moxon Street, London, W1U                 8
# Winnington Road, N2                       8
# Moxon Street, W1U                         7
# Canary Wharf,\r\nLondon, \r\nE14 9QG      5
# Chesham Street, SW1X                      5
# Old Church Street, London, SW3            5
# St. Mary Abbots Place, London, W8         5
# Damac Tower, Nine Elms, London            5
# Lowndes Square, London, SW1X              5
# Grosvenor Square, Mayfair, London, W1K    5
# Name: count, dtype: int64

# %%
ax=df['Street'].value_counts()\
.head(10)\
.plot(kind='bar', title='London Streets')
ax.set_xlabel('Street name')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
# ) missing from current font.
#   func(*args, **kwargs)
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
ax=df['Nearest Station (miles)'].plot(kind='hist', 
                                      bins=25, 
                                      title='Nearest Station in miles')
ax.set_xlabel('Nearest Station (miles)')
# Out:
# Text(0.5, 0, 'Nearest Station (miles)')

# %%
 ax=df['Nearest Station (miles)'].plot(kind='kde',  
                                      title='Nearest Station in miles')
ax.set_xlabel('Nearest Station (miles)')
# Out:
# Text(0.5, 0, 'Nearest Station (miles)')

# %%
df.plot(kind='scatter',
       x='Nearest Station (miles)',
       y='Street',
       title='Nearest station in miles VS Street')
plt.show()
# Out:
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(x='Nearest Station (miles)',
       y='Street',
       data=df)
# Out:
# <Axes: xlabel='Nearest Station (miles)', ylabel='Street'>
# ) missing from current font.\site-packages\IPython\core\events.py:93: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from current font.\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#with sns not mtlb

sns.scatterplot(x='Nearest Station (miles)',
       y='Street',
        hue='Tenure',
       data=df)
# Out:
# <Axes: xlabel='Nearest Station (miles)', ylabel='Street'>
# ) missing from current font.\site-packages\IPython\core\events.py:93: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from current font.\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.pairplot(df, vars=['Bedrooms', 'Bathrooms', 'Tenure', 'Garden'])
plt.show()
# Out:
# C:\Users\parul\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df[['Bedrooms', 'Bathrooms', 'Garden','Price in Pounds']].dropna().corr()
# Out:
#                  Bedrooms  Bathrooms    Garden  Price in Pounds
# Bedrooms         1.000000   0.798116  0.065180         0.370003
# Bathrooms        0.798116   1.000000 -0.009171         0.462460
# Garden           0.065180  -0.009171  1.000000        -0.010678
# Price in Pounds  0.370003   0.462460 -0.010678         1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder= LabelEncoder()

# %%
print(label_encoder)
# Out:
# LabelEncoder()

# %%
df["Street"]=label_encoder.fit_transform(df["Street"])

# %%
df.head()
# Out:
#           ID  Bedrooms  Bathrooms    Tenure  Garden  Street  Size in sqft  \
# 0  132180206       5.0        4.0  freehold       0     354           NaN
# 1  134996630       6.0        5.0  freehold       0     435           NaN
# 2  134169233       7.0        5.0  freehold       1     577           NaN
# 3  132180206       5.0        4.0  freehold       0     354           NaN
# 4  134996630       6.0        5.0  freehold       0     435           NaN
#
#    Price in Pounds       Nearest Station  Nearest Station (miles)  \
# 0         10500000  Holland Park Station                      0.2
# 1          8950000     Wimbledon Station                      0.3
# 2         11950000     Wimbledon Station                      0.7
# 3         10500000  Holland Park Station                      0.2
# 4          8950000     Wimbledon Station                      0.3
#
#   Postcode (outward code)
# 0                     NaN
# 1                    SW19
# 2                    SW19
# ...

# %%
df.dtypes
# Out:
# ID                           int64
# Bedrooms                   float64
# Bathrooms                  float64
# Tenure                      object
# Garden                       int64
# Street                       int32
# Size in sqft               float64
# Price in Pounds              int64
# Nearest Station             object
# Nearest Station (miles)    float64
# Postcode (outward code)     object
# dtype: object

# %%
df["Street"].unique()
# Out:
# array([354, 435, 577, 142, 178, 619, 680, 303,  66, 120, 461, 277, 388,
#        490,   2, 214, 155, 345, 251, 374, 147, 588,  38, 103, 223,  10,
#        665, 533, 267, 618, 434, 626,   6,  76, 428, 528, 676, 379, 357,
#        166, 102, 460,   5, 681, 160, 613,  26, 679, 541, 205, 256, 409,
#         70, 220, 322, 486, 519, 478, 197, 282, 670, 628, 494, 161, 219,
#        564, 317, 249, 638, 502, 447, 331, 646, 692, 239,  43, 280, 525,
#        635, 287, 185, 503, 191, 611, 299,  77, 302, 207, 104, 179, 602,
#        432,  54, 203, 688,  91, 293, 140,  74, 263, 240, 297, 539, 319,
#        449, 497, 456, 123, 610, 242, 394, 673, 617, 570, 154, 109, 682,
#        196, 475, 580, 535, 129,  63,  30, 524, 605, 476, 555,  49, 261,
#        380, 107, 565, 627,  64, 315, 516,  61, 291, 474,  85, 485, 281,
#        604, 396, 333, 595, 392, 640, 168, 393, 522, 390, 657, 690, 210,
#        241, 252,   3, 426, 694, 321,  53, 433, 216, 532, 268,  15,  68,
# ...

# %%
df["Street"].value_counts()
# Out:
# Street
# 432    8
# 692    8
# 434    7
# 104    5
# 129    5
#       ..
# 224    1
# 167    1
# 634    1
# 342    1
# 514    1
# Name: count, Length: 703, dtype: int64
